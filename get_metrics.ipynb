# %%
from pymongo import MongoClient
import pandas as pd

# %%
smells = pd.read_csv('/Users/audreyvasconcelos/Desktop/tcc/smells_metrics.csv')

# %%
smells['smellTypes'].value_counts()
# Out:
# ['LongMethod']                                                             55
# ['FeatureEnvy', 'LongMethod', 'MessageChain']                              31
# ['FeatureEnvy', 'LongMethod']                                              18
# ['FeatureEnvy', 'LongMethod', 'IntensiveCoupling']                          7
# ['FeatureEnvy', 'LongMethod', 'MessageChain', 'DispersedCoupling']          4
# ['FeatureEnvy', 'LongMethod', 'MessageChain', 'IntensiveCoupling']          4
# ['LongMethod', 'IntensiveCoupling']                                         4
# ['LongMethod', 'MessageChain', 'IntensiveCoupling']                         3
# ['FeatureEnvy', 'LongMethod', 'DispersedCoupling']                          2
# ['LongMethod', 'MessageChain']                                              2
# ['LongMethod', 'LongParameterList']                                         2
# ['FeatureEnvy', 'LongMethod', 'MessageChain', 'ShotgunSurgery']             1
# ...

# %%
smells['liststring'] = [''.join(map(str, l)) for l in smells['smellTypes']]

# %%
smells = smells.sort_values('smellTypes').reset_index(drop=True)

# %%
pd.set_option('display.max_rows', 500)
smells
# Out:
#      compositeID                             commit_before  \
# 0     effect-442  e0c330b1c0cdc5393db34e26d68da0c7ea651ce2
# 1     effect-193  655279b97d1f0336caaacb16f0298cb1a638e746
# 2     effect-399  3404ae10f1ebe98a3a4309f6bef93fcae6db2305
# 3    effect-1208  7b121c26aee2f53ad7e03bcc492b40545825aff4
# 4    effect-1376  ab7786be4a8d9f3136772548ad0116b4bab7d8f5
# 5      effect-11  10a0e7796e8a32d9d432c2fb13491452b650f824
# 6      effect-60  c0d6d6c85daf60ea9568e88665ba84a571dee1a7
# 7     effect-399  ac613585b9cca0175fb95298aef6fa54d346cf19
# 8     effect-399  52104a88a4d7a1ad20758f6e66c9704bb8ac9f1b
# 9    effect-1849  465dcc58c03c6d599f3a49264518416a7a608346
# 10     effect-84  ef3735f65b17552a33392b9a27af1f4347a265ec
# 11     effect-85  863d7ab54ad6f91a865ee05cc0111a6fb08e03cf
# 12     effect-84  5601488a877cf64d0110e85f62008f4f95619d3a
# 13     effect-84  ef3735f65b17552a33392b9a27af1f4347a265ec
# 14     effect-85  863d7ab54ad6f91a865ee05cc0111a6fb08e03cf
# ...

# %%
df_fe = smells.loc[0:67]

# %%
df_fe.median()
# Out:
# /var/folders/s0/xswb395510s4jg7pmnk6_zj80000gn/T/ipykernel_15059/168479676.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_fe.median()
# cC                                                                  0.0
# cDISP                                                               0.0
# cINT                                                                0.0
# cLOC                                                                0.0
# changingClasses                                                     0.0
# changingMethods                                                     0.0
# classLinesOfCode                                                    0.0
# couplingDispersion                                                  0.5
# ...

# %%
df_lm = smells.loc[68:135]

# %%
df_lm.median()
# Out:
# /var/folders/s0/xswb395510s4jg7pmnk6_zj80000gn/T/ipykernel_15059/3262862592.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_lm.median()
# cC                                                                  0.00
# cDISP                                                               0.00
# cINT                                                                0.00
# cLOC                                                                0.00
# changingClasses                                                     0.00
# changingMethods                                                     0.00
# classLinesOfCode                                                    0.00
# couplingDispersion                                                  0.75
# ...
